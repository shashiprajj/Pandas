# %% [markdown]
# # Pandas Adding and Removing Columns

# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv")

# %%
df1 = pd.read_csv("csv_file.csv")

# %%
students = {
    "first_name" : ["Shashi", "Meet", "Anshuman", "Prashant", "Vikhil"],
    "last_name" : ["Prajapati", "Thakar", "Tiwari", "Vasala", "Sallagargi"],
    "Roll-no" : [46, 64, 65, 67, 50], 
    "email" : ["shashiprajapati38@gmail.com", "meet@gmail.com", "anshuman@gmail.com", "prashant@gmail.com", "vikhil@gmail.com"]
}

# %%
df2 = pd.DataFrame(students)

# %%
df2
# Out:
#   first_name   last_name  Roll-no                        email
# 0     Shashi   Prajapati       46  shashiprajapati38@gmail.com
# 1       Meet      Thakar       64               meet@gmail.com
# 2   Anshuman      Tiwari       65           anshuman@gmail.com
# 3   Prashant      Vasala       67           prashant@gmail.com
# 4     Vikhil  Sallagargi       50             vikhil@gmail.com

# %% [markdown]
# # Adding and Removing Columns

# %%
df2["first_name"] + ' ' + df2["last_name"]
# Out:
# 0     Shashi Prajapati
# 1          Meet Thakar
# 2      Anshuman Tiwari
# 3      Prashant Vasala
# 4    Vikhil Sallagargi
# dtype: object

# %%
df2["Name"] = (df2["first_name"] + ' ' + df2["last_name"])

# %%
df2
# Out:
#   first_name   last_name  Roll-no                        email  \
# 0     Shashi   Prajapati       46  shashiprajapati38@gmail.com
# 1       Meet      Thakar       64               meet@gmail.com
# 2   Anshuman      Tiwari       65           anshuman@gmail.com
# 3   Prashant      Vasala       67           prashant@gmail.com
# 4     Vikhil  Sallagargi       50             vikhil@gmail.com
#
#                 Name
# 0   Shashi Prajapati
# 1        Meet Thakar
# 2    Anshuman Tiwari
# 3    Prashant Vasala
# 4  Vikhil Sallagargi

# %%
df2.drop(columns=['first_name', 'last_name'], inplace=True)

# %%
df2
# Out:
#    Roll-no                        email               Name
# 0       46  shashiprajapati38@gmail.com   Shashi Prajapati
# 1       64               meet@gmail.com        Meet Thakar
# 2       65           anshuman@gmail.com    Anshuman Tiwari
# 3       67           prashant@gmail.com    Prashant Vasala
# 4       50             vikhil@gmail.com  Vikhil Sallagargi

# %% [markdown]
# # Again splitting name to first_name and last_name

# %%
df2["Name"].str.split(' ')
# Out:
# 0     [Shashi, Prajapati]
# 1          [Meet, Thakar]
# 2      [Anshuman, Tiwari]
# 3      [Prashant, Vasala]
# 4    [Vikhil, Sallagargi]
# Name: Name, dtype: object

# %% [markdown]
# We have got a list, now we will need to expand it into 2 columns

# %%
df2["Name"].str.split(' ', expand=True)
# Out:
#           0           1
# 0    Shashi   Prajapati
# 1      Meet      Thakar
# 2  Anshuman      Tiwari
# 3  Prashant      Vasala
# 4    Vikhil  Sallagargi

# %%
df2[["first_name", "last_name"]] = df2["Name"].str.split(' ', expand=True)

# %%
df2
# Out:
#    Roll-no                        email               Name first_name  \
# 0       46  shashiprajapati38@gmail.com   Shashi Prajapati     Shashi
# 1       64               meet@gmail.com        Meet Thakar       Meet
# 2       65           anshuman@gmail.com    Anshuman Tiwari   Anshuman
# 3       67           prashant@gmail.com    Prashant Vasala   Prashant
# 4       50             vikhil@gmail.com  Vikhil Sallagargi     Vikhil
#
#     last_name
# 0   Prajapati
# 1      Thakar
# 2      Tiwari
# 3      Vasala
# 4  Sallagargi

# %% [markdown]
# # Adding or Removing Rows

# %%
df2.append({"Name": "Amaan Shaikh"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-b245f3d04f2b> in <module>
# ----> 1 df2.append({"Name": "Amaan Shaikh"})
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7704             if isinstance(other, dict):
#    7705                 if not ignore_index:
# -> 7706                     raise TypeError("Can only append a dict if ignore_index=True")
#    7707                 other = Series(other)
#    7708             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %%
df2.append({"Name": "Amaan Shaikh"}, ignore_index=True)  # we can ignore other column values, but that will set to NaN
# Out:
#    Roll-no                        email               Name first_name  \
# 0     46.0  shashiprajapati38@gmail.com   Shashi Prajapati     Shashi
# 1     64.0               meet@gmail.com        Meet Thakar       Meet
# 2     65.0           anshuman@gmail.com    Anshuman Tiwari   Anshuman
# 3     67.0           prashant@gmail.com    Prashant Vasala   Prashant
# 4     50.0             vikhil@gmail.com  Vikhil Sallagargi     Vikhil
# 5      NaN                          NaN       Amaan Shaikh        NaN
#
#     last_name
# 0   Prajapati
# 1      Thakar
# 2      Tiwari
# 3      Vasala
# 4  Sallagargi
# 5         NaN

# %%
student = {
    "first_name" : ["Amaan", "Abhilasha"],
    "last_name" : ["Shaikh", "Deshmukh"],
    "Roll-no" : [52, 12], 
    "email" : ["amaan@gmail.com", "abhilasha@gmail.com"]
}

# %%
df3 = pd.DataFrame(student)

# %% [markdown]
# Adding One dataFrame to Other DatFrame

# %%
df2.append(df3, ignore_index=True)
# Out:
#    Roll-no                        email               Name first_name  \
# 0       46  shashiprajapati38@gmail.com   Shashi Prajapati     Shashi
# 1       64               meet@gmail.com        Meet Thakar       Meet
# 2       65           anshuman@gmail.com    Anshuman Tiwari   Anshuman
# 3       67           prashant@gmail.com    Prashant Vasala   Prashant
# 4       50             vikhil@gmail.com  Vikhil Sallagargi     Vikhil
# 5       52              amaan@gmail.com                NaN      Amaan
# 6       12          abhilasha@gmail.com                NaN  Abhilasha
#
#     last_name
# 0   Prajapati
# 1      Thakar
# 2      Tiwari
# 3      Vasala
# 4  Sallagargi
# 5      Shaikh
# 6    Deshmukh

# %%
df2 = df2.append(df3, ignore_index=True)

# %%
df2
# Out:
#    Roll-no                        email               Name first_name  \
# 0       46  shashiprajapati38@gmail.com   Shashi Prajapati     Shashi
# 1       64               meet@gmail.com        Meet Thakar       Meet
# 2       65           anshuman@gmail.com    Anshuman Tiwari   Anshuman
# 3       67           prashant@gmail.com    Prashant Vasala   Prashant
# 4       50             vikhil@gmail.com  Vikhil Sallagargi     Vikhil
# 5       52              amaan@gmail.com                NaN      Amaan
# 6       12          abhilasha@gmail.com                NaN  Abhilasha
#
#     last_name
# 0   Prajapati
# 1      Thakar
# 2      Tiwari
# 3      Vasala
# 4  Sallagargi
# 5      Shaikh
# 6    Deshmukh

# %%
df2.drop(index=6)       # deleting a row by giving index
# Out:
#    Roll-no                        email               Name first_name  \
# 0       46  shashiprajapati38@gmail.com   Shashi Prajapati     Shashi
# 1       64               meet@gmail.com        Meet Thakar       Meet
# 2       65           anshuman@gmail.com    Anshuman Tiwari   Anshuman
# 3       67           prashant@gmail.com    Prashant Vasala   Prashant
# 4       50             vikhil@gmail.com  Vikhil Sallagargi     Vikhil
# 5       52              amaan@gmail.com                NaN      Amaan
#
#     last_name
# 0   Prajapati
# 1      Thakar
# 2      Tiwari
# 3      Vasala
# 4  Sallagargi
# 5      Shaikh

# %%
filt2 =df2[df2["first_name"] == "Abhilasha"]
df2.drop(index = filt2.index)
# Out:
#   first_name   last_name  Roll-no                        email
# 0     Shashi   Prajapati       46  shashiprajapati38@gmail.com
# 1       Meet      Thakar       64               meet@gmail.com
# 2   Anshuman      Tiwari       65           anshuman@gmail.com
# 3   Prashant      Vasala       67           prashant@gmail.com
# 4     Vikhil  Sallagargi       50             vikhil@gmail.com

# %%
student = {
    "first_name" : ["Amaan", "Abhilasha"],
    "last_name" : ["Shaikh", "Deshmukh"], 
    "email" : ["amaan@gmail.com", "abhilasha@gmail.com"]
}

# %%
df4 = pd.DataFrame(student)

# %%
df2.append(df4, ignore_index=True)
# Out:
#   first_name   last_name  Roll-no                        email
# 0     Shashi   Prajapati     46.0  shashiprajapati38@gmail.com
# 1       Meet      Thakar     64.0               meet@gmail.com
# 2   Anshuman      Tiwari     65.0           anshuman@gmail.com
# 3   Prashant      Vasala     67.0           prashant@gmail.com
# 4     Vikhil  Sallagargi     50.0             vikhil@gmail.com
# 5      Amaan      Shaikh      NaN              amaan@gmail.com
# 6  Abhilasha    Deshmukh      NaN          abhilasha@gmail.com

# %%
df2.dropna()    # rows containing NaN dropped
# Out:
#   first_name   last_name  Roll-no                        email
# 0     Shashi   Prajapati       46  shashiprajapati38@gmail.com
# 1       Meet      Thakar       64               meet@gmail.com
# 2   Anshuman      Tiwari       65           anshuman@gmail.com
# 3   Prashant      Vasala       67           prashant@gmail.com
# 4     Vikhil  Sallagargi       50             vikhil@gmail.com

# %%
df2
# Out:
#   first_name   last_name  Roll-no                        email
# 0     Shashi   Prajapati       46  shashiprajapati38@gmail.com
# 1       Meet      Thakar       64               meet@gmail.com
# 2   Anshuman      Tiwari       65           anshuman@gmail.com
# 3   Prashant      Vasala       67           prashant@gmail.com
# 4     Vikhil  Sallagargi       50             vikhil@gmail.com
