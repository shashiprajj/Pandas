# %% [markdown]
# # Pandas Sorting Data

# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv")

# %%
df1 = pd.read_csv("csv_file.csv")

# %%
students = {
    "first_name" : ["Shashi", "Meet", "Anshuman", "Prashant", "Vikhil"],
    "last_name" : ["Prajapati", "Thakar", "Tiwari", "Vasala", "Sallagargi"],
    "Roll-no" : [46, 64, 65, 67, 50], 
    "email" : ["shashiprajapati38@gmail.com", "meet@gmail.com", "anshuman@gmail.com", "prashant@gmail.com", "vikhil@gmail.com"]
}

# %%
df2 = pd.DataFrame(students)

# %%
df1
# Out:
#        Name  Roll no Batch  Maths 1  Maths 2  Maths 3
# 0    Shashi       46    B2       80       75       85
# 1      Meet       64    B3       85       78       79
# 2  Anshuman       65    B3       90       86       91
# 3  Prashant       67    B3       94       68       45
# 4    Vikhil       50    B2       78       45       85
# 5     Amaan       52    B2       85       35       65
# 6    Harish       27    B2       45       41       78

# %%
df1.sort_values(by="Name")
# Out:
#        Name  Roll no Batch  Maths 1  Maths 2  Maths 3
# 5     Amaan       52    B2       85       35       65
# 2  Anshuman       65    B3       90       86       91
# 6    Harish       27    B2       45       41       78
# 1      Meet       64    B3       85       78       79
# 3  Prashant       67    B3       94       68       45
# 0    Shashi       46    B2       80       75       85
# 4    Vikhil       50    B2       78       45       85

# %%
df1.sort_values(by="Name", ascending=False)
# Out:
#        Name  Roll no Batch  Maths 1  Maths 2  Maths 3
# 4    Vikhil       50    B2       78       45       85
# 0    Shashi       46    B2       80       75       85
# 3  Prashant       67    B3       94       68       45
# 1      Meet       64    B3       85       78       79
# 6    Harish       27    B2       45       41       78
# 2  Anshuman       65    B3       90       86       91
# 5     Amaan       52    B2       85       35       65

# %%
df1.sort_values(by=["Name",  "Roll no"], ascending=False)    # sort by multiple columns
# Out:
#        Name  Roll no Batch  Maths 1  Maths 2  Maths 3
# 4    Vikhil       50    B2       78       45       85
# 0    Shashi       46    B2       80       75       85
# 3  Prashant       67    B3       94       68       45
# 1      Meet       64    B3       85       78       79
# 6    Harish       27    B2       45       41       78
# 2  Anshuman       65    B3       90       86       91
# 5     Amaan       52    B2       85       35       65

# %%
df1.sort_values(by=["Name",  "Roll no"], ascending=[False, True], inplace = True)    # sort by multiple columns

# %%
df1
# Out:
#        Name  Roll no Batch  Maths 1  Maths 2  Maths 3
# 4    Vikhil       50    B2       78       45       85
# 0    Shashi       46    B2       80       75       85
# 3  Prashant       67    B3       94       68       45
# 1      Meet       64    B3       85       78       79
# 6    Harish       27    B2       45       41       78
# 2  Anshuman       65    B3       90       86       91
# 5     Amaan       52    B2       85       35       65

# %%
df1.sort_index() # sort by index no
# Out:
#        Name  Roll no Batch  Maths 1  Maths 2  Maths 3
# 0    Shashi       46    B2       80       75       85
# 1      Meet       64    B3       85       78       79
# 2  Anshuman       65    B3       90       86       91
# 3  Prashant       67    B3       94       68       45
# 4    Vikhil       50    B2       78       45       85
# 5     Amaan       52    B2       85       35       65
# 6    Harish       27    B2       45       41       78

# %%
df1["Name"].sort_values()
# Out:
# 5       Amaan
# 2    Anshuman
# 6      Harish
# 1        Meet
# 3    Prashant
# 0      Shashi
# 4      Vikhil
# Name: Name, dtype: object

# %% [markdown]
# # Working on Large Data (df)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.sort_values(by="Country", inplace=True)

# %%
df[["Respondent", "Country", "ConvertedComp"]].head(50)
# Out:
#        Respondent      Country  ConvertedComp
# 39018       39258  Afghanistan        19152.0
# 62723       63129  Afghanistan      1000000.0
# 85185       85715  Afghanistan            NaN
# 50437       50767  Afghanistan            NaN
# 88340        2782  Afghanistan            NaN
# 88735       63019  Afghanistan            NaN
# 6391         6417  Afghanistan            NaN
# 39754       40000  Afghanistan            NaN
# 88181       88731  Afghanistan            NaN
# 48122       48436  Afghanistan         4464.0
# 10697       10746  Afghanistan         3996.0
# 62124       62525  Afghanistan            NaN
# 49377       49702  Afghanistan            NaN
# 32971       33178  Afghanistan            NaN
# 60559       60946  Afghanistan            NaN
# 85827       86362  Afghanistan            NaN
# 88033       88582  Afghanistan            NaN
# 28470       28638  Afghanistan            0.0
# 719           722  Afghanistan            0.0
# ...

# %%
df.sort_values(by=["Country", "ConvertedComp"], inplace=True)

# %%
df[["Respondent", "Country", "ConvertedComp"]].head(50)
# Out:
#        Respondent      Country  ConvertedComp
# 28470       28638  Afghanistan            0.0
# 719           722  Afghanistan            0.0
# 29560       29736  Afghanistan         1116.0
# 8112         8149  Afghanistan         1596.0
# 10697       10746  Afghanistan         3996.0
# 48122       48436  Afghanistan         4464.0
# 22327       22450  Afghanistan         7980.0
# 7056         7085  Afghanistan        14364.0
# 58082       58450  Afghanistan        17556.0
# 39018       39258  Afghanistan        19152.0
# 50172       50499  Afghanistan       153216.0
# 62723       63129  Afghanistan      1000000.0
# 85185       85715  Afghanistan            NaN
# 50437       50767  Afghanistan            NaN
# 88340        2782  Afghanistan            NaN
# 88735       63019  Afghanistan            NaN
# 6391         6417  Afghanistan            NaN
# 39754       40000  Afghanistan            NaN
# 88181       88731  Afghanistan            NaN
# ...

# %%
df["ConvertedComp"].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, "ConvertedComp")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 25833       25983                     I am a developer by profession      Yes
# 87353       87896                     I am a developer by profession      Yes
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 77665       78151                     I am a developer by profession      Yes
# 79701       80200                     I am a developer by profession      Yes
# 51798       52132                     I am a developer by profession      Yes
# 75088       75561                     I am a developer by profession      Yes
# 32056       32250                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
df.nsmallest(10, "ConvertedComp")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 28470       28638                     I am a developer by profession      Yes
# 719           722                     I am a developer by profession       No
# 13760       13825                     I am a developer by profession      Yes
# 40655       40913                     I am a developer by profession      Yes
# 30447       30630                     I am a developer by profession      Yes
# 68611       69049                     I am a developer by profession       No
# 19235       19340  I am not primarily a developer, but I write co...      Yes
# 16126       16214  I am not primarily a developer, but I write co...      Yes
# 29184       29355                     I am a developer by profession      Yes
# 1678         1685                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...
